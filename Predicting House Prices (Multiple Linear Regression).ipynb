# %%
# Import necessary libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

# %%
# ------------------------------------------------------
# 1. Load the Dataset
# ------------------------------------------------------
data = pd.read_csv("./dataset/Housing.csv") # Load housing data
df = pd.DataFrame(data) # Convert to DataFrame
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# ------------------------------------------------------
# 2. Prepare Features and Target
# ------------------------------------------------------
# Independent variables (features)
x = df[['area', 'bedrooms', 'bathrooms']]

# Dependent variable (target)
y = df[['price']]

# %%
# ------------------------------------------------------
# 3. Train-Test Split
# ------------------------------------------------------
# Split the data into training (20%) and testing (80%)
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.2, random_state=0)

# %%
# ------------------------------------------------------
# 4. Visualize the Data
# ------------------------------------------------------
# Plot histograms for feature distribution
x.hist(figsize=(8, 6), bins=15)
plt.suptitle("Feature Distribution")
plt.show()

# Plot histogram for target variable (price)
y.hist(figsize=(5, 4), bins=15)
plt.suptitle("Target (Price) Distribution")
plt.show()

# %%
# ------------------------------------------------------
# 5. Train the Linear Regression Model
# ------------------------------------------------------
model = LinearRegression()
model.fit(x_train, y_train)  # Fit model on training data
# Out:
# LinearRegression()

# %%
# ------------------------------------------------------
# 6. Make Predictions
# ------------------------------------------------------
y_pred = model.predict(x_test)

# %%
# ------------------------------------------------------
# 7. Evaluate Model Performance
# ------------------------------------------------------
print(f"Mean Absolute Error: {mean_absolute_error(y_test, y_pred):.2f}")
print(f"R-squared Score: {r2_score(y_test, y_pred):.4f}")
# Out:
# Mean Absolute Error: 1005270.43
# R-squared Score: 0.5008

# %%
# ------------------------------------------------------
# 8. Predict Price for a New House
# ------------------------------------------------------
# Predict price for a house with 2500 sqft, 4 bedrooms, 3 bathrooms
new_house = pd.DataFrame([[2500, 4, 3]], columns=['area', 'bedrooms', 'bathrooms'])
predicted_price = model.predict(new_house)

print(f"Predicted price for the new house: ${predicted_price.flatten()[0]:,.2f}")
# Out:
# Predicted price for the new house: $6,841,959.75
